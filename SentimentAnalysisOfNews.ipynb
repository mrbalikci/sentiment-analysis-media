# %%
import tweepy
import json
from twitter__api import (api_key, api_secret, access_token, access_token_secret)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_users = ("@BBC", "@CBS", "@CNN", "@FoxNews", "@nytimes")
print(target_users)
# Out:
# ('@BBC', '@CBS', '@CNN', '@FoxNews', '@nytimes')

# %%
# target_user = input('Please choose one news platform from above list for sentiments analysis ')

# %%
# print(target_user)

# %%
# Target Account

target_user = "FoxNews"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        print(json.dumps(tweet, indent = 4 , sort_keys = True))
        # Add sentiments for each tweet into an array
        sentiments.append({"Date": tweet["created_at"],
                           'Text': tweet['text'], 
                           'Source': tweet['source'],
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "Name": target_user})
        
        # Add to counter 
        counter = counter + 1
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Wed Nov 29 20:18:51 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "foxnews.com/us/2017/11/29/\u2026",
#                 "expanded_url": "http://www.foxnews.com/us/2017/11/29/missing-north-carolina-toddler-may-have-been-spotted-at-walmart-fbi-says.html",
#                 "indices": [
#                     74,
#                     97
#                 ],
#                 "url": "https://t.co/vIHqTlrATc"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 32,
#     "favorited": false,
#     "geo": null,
#     "id": 935966305903104002,
#     "id_str": "935966305903104002",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
# ...

# %%
len(sentiments)
# Out:
# 100

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
cols = ['Name', 'Tweets Ago', 'Date','Compound', 'Negative', 'Neutral', 'Positive', 'Text', 'Source']
sentiments_pd = sentiments_pd.reindex(columns = cols)
sentiments_pd
# Out:
#        Name  Tweets Ago                            Date  Compound  Negative  \
# 0   FoxNews           1  Wed Nov 29 20:18:51 +0000 2017   -0.2960     0.845
# 1   FoxNews           2  Wed Nov 29 20:12:06 +0000 2017   -0.5574     0.753
# 2   FoxNews           3  Wed Nov 29 20:05:46 +0000 2017   -0.7579     0.629
# 3   FoxNews           4  Wed Nov 29 19:58:16 +0000 2017   -0.2732     0.718
# 4   FoxNews           5  Wed Nov 29 19:56:27 +0000 2017    0.0000     1.000
# 5   FoxNews           6  Wed Nov 29 19:54:07 +0000 2017    0.0000     1.000
# 6   FoxNews           7  Wed Nov 29 19:49:52 +0000 2017    0.0000     1.000
# 7   FoxNews           8  Wed Nov 29 19:48:11 +0000 2017    0.5106     0.823
# 8   FoxNews           9  Wed Nov 29 19:43:47 +0000 2017    0.0000     1.000
# 9   FoxNews          10  Wed Nov 29 19:39:44 +0000 2017    0.0000     1.000
# 10  FoxNews          11  Wed Nov 29 19:36:58 +0000 2017    0.2484     0.900
# ...

# %%
sentiments_pd.to_csv('SentimentAnalysisFoxNews.csv')

# %%
# Create plot
plt.plot(np.arange(len(fownews_sentiments_pd["Compound"])),
         fownews_sentiments_pd["Compound"], marker="o", linewidth=0.5,
         alpha=0.8, color = 'b', label = '@FoxNews')

# # Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title("Sentiment Analysis of Tweets ({}) for {}".format(now, target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.ylim(-1, 1)
art = []
plt.style.use('seaborn-darkgrid')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("SentimentAnalysisOfTweetsOfFoxNews", additional_artists=art, bbox_inches="tight")
plt.show()

# %%
sentiments_targets = []


for target in target_users:
    
    for x in range(5):

    # Get all tweets from home feed
        public_tweets = api.user_timeline(target)

    # Loop through all tweets 
        for tweet in public_tweets:

        # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]
            tweets_ago = counter
        
            # print(json.dumps(tweet, indent = 4 , sort_keys = True))
            # Add sentiments for each tweet into an array
            sentiments_targets.append({"Date": tweet["created_at"],
                           'Text': tweet['text'], 
                           'Source': tweet['source'],
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "Name": target})

# %%
len(sentiments_targets)
# Out:
# 500

# %%
sentiments_targets_pd = pd.DataFrame.from_dict(sentiments_targets)
cols = ['Name', 'Tweets Ago', 'Date','Compound', 'Negative', 'Neutral', 'Positive', 'Text', 'Source']
sentiments_targets_pd = sentiments_targets_pd.reindex(columns = cols)
sentiments_targets_pd
# Out:
#          Name  Tweets Ago                            Date  Compound  Negative  \
# 0        @BBC         101  Wed Nov 29 19:48:10 +0000 2017    0.0000     1.000
# 1        @BBC         101  Wed Nov 29 19:45:53 +0000 2017   -0.3182     0.867
# 2        @BBC         101  Wed Nov 29 19:43:46 +0000 2017    0.0000     1.000
# 3        @BBC         101  Wed Nov 29 19:41:46 +0000 2017    0.0000     1.000
# 4        @BBC         101  Wed Nov 29 19:38:12 +0000 2017    0.5267     0.726
# 5        @BBC         101  Wed Nov 29 19:36:04 +0000 2017    0.9439     0.582
# 6        @BBC         101  Wed Nov 29 19:35:48 +0000 2017    0.0000     1.000
# 7        @BBC         101  Wed Nov 29 19:35:44 +0000 2017    0.0000     1.000
# 8        @BBC         101  Wed Nov 29 19:28:04 +0000 2017    0.4767     0.654
# 9        @BBC         101  Wed Nov 29 19:05:03 +0000 2017    0.0000     1.000
# 10       @BBC         101  Wed Nov 29 18:33:04 +0000 2017    0.0000     1.000
# ...

# %%
compound_news = sentiments_targets_pd.pivot(index='Tweets Ago', columns='Name', values='Compound')
compound_news.plot(marker = 'o', grid= True, style=' ', ms=10)
plt.show()
